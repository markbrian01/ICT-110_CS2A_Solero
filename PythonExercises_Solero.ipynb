# %% [markdown]
# Chapter 1

# %% [markdown]
# Exercise 1

# %%
print('Hello world!') #the word print is in capital letter, i just change it to lowercase
# Out:
# Hello world!

# %%
print('Hello world!') #there is no open parenthesis
# Out:
# Hello world!

# %%
print('Hello world!') #lacks an apostrophe at the end of the text
# Out:
# Hello world!

# %%
print('Hello world!') #there's an extra apostrophe at the end
# Out:
# Hello world!

# %% [markdown]
# Exercise 2

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44

# %% [markdown]
# Exercise 3

# %%
x = 43        #I'll just change the uppercase X to lowercase
x = x + 1
print(x)
# Out:
# 44

# %% [markdown]
# Chapter 2

# %% [markdown]
# Exercise 1

# %%
name = input('Enter your name: ')
print('Hello', name)
# Out:
# Enter your name: Mark
# Hello Mark

# %% [markdown]
# Exercise 2

# %%
hours = input('Enter Hours: ')
rate = input('Enter Rate: ')

Pay = int(hours) * float(rate)

print(Pay)
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# 96.25

# %% [markdown]
# Exercise 4

# %%
num = input('Enter a number: ')

sq = int(num)**2

print('The square of', num + ' is', sq)
# Out:
# Enter a number: 3
# The square of 3 is 9

# %% [markdown]
# Exercise 3

# %%
width = 17
height = 12.0

width//2
width/2.0
height/3
1 + 2 * 5
# Out:
# 11

# %% [markdown]
# Challenge

# %%
cel = input('Enter the temperature in Celsius: ')

fahr = (int(cel) * 9/5) + 32

print('Temperature in Fahrenehit: ', fahr)
# Out:
# Enter the temperature in Celsius: 0
# Temperature in Fahrenehit:  32.0
