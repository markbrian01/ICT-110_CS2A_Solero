# %%
#Chapter 1 - Exercises

# %% [markdown]
# Exercise 1:

# %% [markdown]
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
Print('Hello world!') #The syntax of print is in capital letter, it should in lowercase.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0259f83af1cd> in <cell line: 1>()
# ----> 1 Print('Hello world!') #the word print is in capital letter, i just change it to lowercase
#
# NameError: name 'Print' is not defined

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print'Hello world!') #Syntax error because it lacks an open parenthesis
# Out:
#   File "<ipython-input-8-558af9c05420>", line 1
#     print'Hello world!') #Syntax error because it lacks an open parenthesis
#                        ^
# SyntaxError: unmatched ')'

# %%
print('Hello World!')
# Out:
# Hello World!

# %%
print('Hello world!)
#The syntax lacks a single quote.
# Out:
#   File "<ipython-input-13-ccc7cac48bcd>", line 1
#     print('Hello world!)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
print('Hello world!'')
#There's an extra quote in the syntax.
# Out:
#   File "<ipython-input-11-b036dae910ea>", line 1
#     print('Hello world!'')
#                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# Exercise 2:

# %% [markdown]
# What is the output of the code below?

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44

# %% [markdown]
# Exercise 3:

# %% [markdown]
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = X + 1         #The variable X is not defined. So, I replace it with a lowercase x.
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-471fadd8fdaa> in <cell line: 2>()
#       1 x = 43
# ----> 2 x = X + 1         #The variable X is not defined.
#       3 print(x)
#
# NameError: name 'X' is not defined

# %%
x = 43
x = x + 1
print(x)
# Out:
# 44

# %%
# !git config --global user.name =  'markbrian01'
# !git config --global user.email = 'markbrian.solero@students.isatu.edu.ph'
# !git config --global user.password = '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'

# %%
# !git clone https://markbrian01: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@github.com/markbrian01/ICT-110_CS2A_Solero.git
# Out:
# Cloning into 'ICT-110_CS2A_Solero'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 1), reused 5 (delta 0), pack-reused 0
# Receiving objects: 100% (6/6), done.
# Resolving deltas: 100% (1/1), done.

# %%
# !cp "/content/drive/MyDrive/Colab Notebooks/Chapter 1 - Exercises.ipynb" "/content/ICT-110_CS2A_Solero/Workbook_01"

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/ICT-110_CS2A_Solero/
# Out:
# /content/ICT-110_CS2A_Solero
